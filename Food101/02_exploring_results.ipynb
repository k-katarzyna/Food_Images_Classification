# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "3"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'

from tensorflow.keras import backend as K
K.clear_session()

# %%
from joblib import load, dump
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from lime.lime_image import LimeImageExplainer
from skimage.segmentation import mark_boundaries
from skimage.filters import gaussian

import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, accuracy_score

from src.data_preprocessing import load_and_prep_image
from src.use_model import make_prediction, LABEL_NAMES, MODEL
from src.training_evaluation import IMG_SIZE

pd.set_option("display.max_rows", 101)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# # Results analysis

# %%
test_data, _ = image_dataset_from_directory("food101_test",
                                             validation_split=0.2,
                                             image_size=(IMG_SIZE, IMG_SIZE),
                                             seed=42,
                                             subset="both"
                                            )

# %%
test_data = test_data.rebatch(1)

results = {
    "labels": [],
    "predictions": []
}
wrong_preds = {
    "image": [],
    "label": [],
    "pred": []
}

for image, label in test_data:
    label = int(label.numpy()[0])
    pred = int(tf.argmax(MODEL.predict(image, verbose=0), axis=1).numpy()[0])
    
    results["labels"].append(label)
    results["predictions"].append(pred)

    if label != pred:
        wrong_preds["image"].append(image[0]/255)
        wrong_preds["label"].append(label)
        wrong_preds["pred"].append(pred)

dump(results, "results/results.pkl")
dump(wrong_preds, "results/wrong_preds.pkl")

print(f"Test accuracy: {np.round(accuracy_score(results["labels"], results["predictions"]), 3)}")
# Out:
# Test accuracy: 0.835

# %%
df = (pd.DataFrame(classification_report(results["labels"],
                                         results["predictions"],
                                         output_dict=True))
      .T.iloc[:-3, :]
      .rename({"support": "n_samples"}, axis=1)
     )
df["label_name"] = LABEL_NAMES
df["n_samples"] = df["n_samples"].astype(int)
df.style.background_gradient(subset=["f1-score"]).format(subset=df.columns[:-2], formatter="{:.2f}")
# Out:
# <style type="text/css">
# #T_44990_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_44990_row1_col2, #T_44990_row60_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_44990_row2_col2 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_44990_row3_col2, #T_44990_row88_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_44990_row4_col2, #T_44990_row26_col2, #T_44990_row77_col2 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_44990_row5_col2, #T_44990_row75_col2 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_44990_row6_col2, #T_44990_row40_col2 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_44990_row7_col2 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_44990_row8_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_44990_row9_col2 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_44990_row10_col2, #T_44990_row30_col2 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_44990_row11_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_44990_row12_col2 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_44990_row13_col2, #T_44990_row44_col2 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_44990_row14_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_44990_row15_col2 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_44990_row16_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_44990_row17_col2 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_44990_row18_col2, #T_44990_row22_col2 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_44990_row19_col2, #T_44990_row99_col2 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_44990_row20_col2 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_44990_row21_col2, #T_44990_row71_col2 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_44990_row23_col2, #T_44990_row59_col2, #T_44990_row74_col2 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_44990_row24_col2 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_44990_row25_col2, #T_44990_row66_col2, #T_44990_row91_col2 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_44990_row27_col2, #T_44990_row98_col2 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_44990_row28_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_44990_row29_col2, #T_44990_row69_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_44990_row31_col2 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_44990_row32_col2, #T_44990_row46_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_44990_row33_col2 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_44990_row34_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_44990_row35_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_44990_row36_col2, #T_44990_row52_col2 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_44990_row37_col2, #T_44990_row49_col2 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_44990_row38_col2, #T_44990_row89_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_44990_row39_col2 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_44990_row41_col2, #T_44990_row51_col2, #T_44990_row63_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_44990_row42_col2 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_44990_row43_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_44990_row45_col2 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_44990_row47_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_44990_row48_col2 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_44990_row50_col2 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_44990_row53_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_44990_row54_col2 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_44990_row55_col2 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_44990_row56_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_44990_row57_col2 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_44990_row58_col2 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_44990_row61_col2 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_44990_row62_col2, #T_44990_row68_col2 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_44990_row64_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_44990_row65_col2 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_44990_row67_col2 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_44990_row70_col2 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_44990_row72_col2 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_44990_row73_col2 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_44990_row76_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_44990_row78_col2 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_44990_row79_col2 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_44990_row80_col2 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_44990_row81_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_44990_row82_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_44990_row83_col2 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_44990_row84_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_44990_row85_col2 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_44990_row86_col2 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_44990_row87_col2 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_44990_row90_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_44990_row92_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_44990_row93_col2 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_44990_row94_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_44990_row95_col2 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_44990_row96_col2 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_44990_row97_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_44990_row100_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# </style>
# <table id="T_44990">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44990_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_44990_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_44990_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_44990_level0_col3" class="col_heading level0 col3" >n_samples</th>
#       <th id="T_44990_level0_col4" class="col_heading level0 col4" >label_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44990_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44990_row0_col0" class="data row0 col0" >0.70</td>
#       <td id="T_44990_row0_col1" class="data row0 col1" >0.58</td>
#       <td id="T_44990_row0_col2" class="data row0 col2" >0.64</td>
#       <td id="T_44990_row0_col3" class="data row0 col3" >198</td>
#       <td id="T_44990_row0_col4" class="data row0 col4" >apple_pie</td>
#     </tr>
#     <tr>
#       <th id="T_44990_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44990_row1_col0" class="data row1 col0" >0.83</td>
#       <td id="T_44990_row1_col1" class="data row1 col1" >0.85</td>
#       <td id="T_44990_row1_col2" class="data row1 col2" >0.84</td>
#       <td id="T_44990_row1_col3" class="data row1 col3" >208</td>
#       <td id="T_44990_row1_col4" class="data row1 col4" >baby_back_ribs</td>
#     </tr>
#     <tr>
#       <th id="T_44990_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44990_row2_col0" class="data row2 col0" >0.80</td>
#       <td id="T_44990_row2_col1" class="data row2 col1" >0.80</td>
#       <td id="T_44990_row2_col2" class="data row2 col2" >0.80</td>
#       <td id="T_44990_row2_col3" class="data row2 col3" >203</td>
#       <td id="T_44990_row2_col4" class="data row2 col4" >bruschetta</td>
#     </tr>
#     <tr>
#       <th id="T_44990_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44990_row3_col0" class="data row3 col0" >0.91</td>
#       <td id="T_44990_

# %% [markdown]
# # Wrong predictions

# %%
wrong_pred_labels = np.array(wrong_preds["label"])
wrong_pred_preds = np.array(wrong_preds["pred"])
analysis = {}
for idx in df.loc[df["f1-score"] < 0.75].index.values:
    idx = int(idx)
    idxs = np.where(idx == wrong_pred_labels)[0]
    class_wrong_preds = Counter(wrong_pred_preds[idxs])
    analysis[LABEL_NAMES[idx]] = [f"{LABEL_NAMES[key]} ({f"{value / len(idxs):.0%}"})" 
                                  for key, value in class_wrong_preds.most_common(3)]
analysis = pd.DataFrame(analysis).T.set_axis(["1st", "2nd", "3rd"], axis=1)
analysis.columns = pd.MultiIndex.from_tuples([("Most common mistakes for worst predicted classes (F1 score < 0.75)", col)
                                              for col in analysis.columns])
analysis
# Out:
#                  Most common mistakes for worst predicted classes (F1 score < 0.75)  \
#                                                                                 1st
# apple_pie                                       bread_pudding (29%)
# ceviche                                          tuna_tartare (16%)
# cheesecake                               strawberry_shortcake (21%)
# chocolate_mousse                               chocolate_cake (44%)
# crab_cakes                                           scallops (25%)
# filet_mignon                                            steak (55%)
# foie_gras                                        cheese_plate (10%)
# gnocchi                                              scallops (13%)
# beet_salad                                      caprese_salad (20%)
# huevos_rancheros                            breakfast_burrito (12%)
# pork_chop                                               steak (30%)
# bread_pudding                                       apple_pie (19%)
# ravioli                                               gnocchi (25%)
# risotto                                            fried_rice (18%)
# steak                                            filet_mignon (37%)
# tuna_tartare                                     beef_tartare (25%)
#
#
#                                      2nd                     3rd
# apple_pie                   baklava (8%)           beignets (6%)
# ceviche           shrimp_and_grits (10%)                pho (8%)
# cheesecake             panna_cotta (12%)       carrot_cake (12%)
# chocolate_mousse       panna_cotta (11%)          ice_cream (7%)
# crab_cakes                takoyaki (11%)          pork_chop (9%)
# filet_mignon             pork_chop (15%)          prime_rib (8%)
# foie_gras               beet_salad (10%)       filet_mignon (8%)
# gnocchi           shrimp_and_grits (13%)           ceviche (11%)
# beet_salad             beef_tartare (7%)       tuna_tartare (7%)
# huevos_rancheros             tacos (10%)            ravioli (9%)
# pork_chop             filet_mignon (19%)    grilled_salmon (12%)
# bread_pudding         french_toast (11%)   chocolate_mousse (6%)
# ravioli                    scallops (8%)     beef_carpaccio (8%)
# risotto                    gnocchi (16%)  shrimp_and_grits (14%)
# steak                    pork_chop (18%)         prime_rib (14%)
# tuna_tartare            beet_salad (20%)         foie_gras (12%)

# %% [markdown]
# It's not surprising that most prediction errors occur, as the mistaken dishes can look very similar. It also turned out that errors appear in the test data as well, even though, according to the dataset description, they were supposed to occur only in the training data.

# %%
idxs = np.random.choice(range(len(wrong_pred_preds)), 8)

fig, ax = plt.subplots(2, 4, figsize=(22, 10))
ax = ax.flatten()
for i, (image, label, pred) in enumerate(zip(np.array(wrong_preds["image"])[idxs],
                                             wrong_pred_labels[idxs],
                                             wrong_pred_preds[idxs]
                                            )):
    ax[i].imshow(image)
    ax[i].axis("off")
    ax[i].set_title(f"True: {LABEL_NAMES[label]}\nPred: {LABEL_NAMES[pred]}", fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# # How the model makes decisions

# %%
explainer = LimeImageExplainer()

def explain_image(image, explainer=explainer, model=MODEL):
    
    if isinstance(image, str):
        image = tf.squeeze(load_and_prep_image(image))
    elif isinstance(image, tf.Tensor):
        pass

    explanation = explainer.explain_instance(
        image.numpy(), 
        classifier_fn=model.predict,
        top_labels=1,
        hide_color=0,
        num_samples=1000,
        random_seed=42
    )
    label = np.argmax(model.predict(tf.expand_dims(image, axis=0), verbose=False))
    temp, mask = explanation.get_image_and_mask(
        label,
        positive_only=True,
        num_features=10,
        hide_rest=False
    )
    
    blurred_image = gaussian(temp, sigma=1.5)
    temp[mask == 0] = blurred_image[mask == 0]
    final_image = temp/255.
    final_image = mark_boundaries(final_image, mask, color=(0, 0, 0))

    return final_image, label

image, label = explain_image("images/test/cheesecake.jpg")
plt.figure(figsize=(4, 4))
plt.imshow(image)
plt.axis('off')
plt.title(LABEL_NAMES[label])
plt.show()
